# %%
import pandas as pd

df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

print(df.shape)
df.columns
# Out:
# (891, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Passenger ID- An index assigned to each passenger
# Survived- 1-> Survived , 0->Dead
# Pclass- Indicates their status in society
#             1- High Class
#             2- Middle Class
#             3- Lower Class
# Name- Name of the passenger
# Sex- Indicates a persons gender
# Age- Indicates the age of a person
# Sibsp-Indicates the Siblings/Spouse of a passenger aboard the Titanic
# Parch- Inicates the number of parents/children of a passenger aboard the Titanic
# Ticket- Refers to the ticket number of a passsenger
# Fare-  Price paid by a passenger
# Cabin- Cabin number of a passenger
# Embarked- Indicates the City from which a passenger boarded the Titanic
#             P-Portsmusth
#             S-Southampton
#             C-Cherbourg

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# A lot of cabin numbers are unaccounted for
# The same can be said for the age of the passengers
# Almost all the pasengers departure ports are available

# %%
df["Survived"].sum()
#The titanic crashed into an iceberg mid voyage which is the reason why many people lost their lives
# Out:
# np.int64(342)

# %% [markdown]
# 342 Survived  and 549 Died
# Mortality rate= 61.62%
# Event is classified as Catastrophe(level 5+ event

# %%
sex_counts = (df["Sex"]).value_counts()
embarked_counts = df["Embarked"].value_counts()

print(sex_counts)
print(embarked_counts)

# %% [markdown]
# Majority passengers are from Southampton

# %%
df.groupby("Sex")["Survived"].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %% [markdown]
# More females survived as compared to men because they were given priorities for life boats

# %%
import matplotlib.pyplot as plt

df.groupby("Embarked")["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Embarked,Survived'>

# %% [markdown]
# Many people who boarded from Southampton lost their lives

# %%
df.groupby("Sex")["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
df.groupby("Pclass")["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Pclass,Survived'>

# %%
import matplotlib.pyplot as plt
survivors = df[df["Survived"] == 1]
counts = survivors["Pclass"].value_counts()

counts.plot(kind="pie",autopct="%1.1f%%")

plt.title("Survival Distribution by Pclass")

plt.show()
